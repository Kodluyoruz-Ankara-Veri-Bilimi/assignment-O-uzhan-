# %%
import pandas as pd 
import seaborn as sns

class Visilation():
    def __init__(self):
    
    def scatter(self,df,x,y,z = None):
        pass
    
    def hist(self,x):
        hist = sns.distplot(x,rug=True, rug_kws={"color": "g"},
                            kde_kws={"color": "k", "lw": 3, "label": "KDE"},
                            hist_kws={"histtype": "step", "linewidth": 3,
                                      "alpha": 1, "color": "g"}))
        return hist
    
    def barh(self,df,x,y,z = None):
        pass
    
    
    def boxplot(self):
        pass
    
    def heatmap(self):
        pass
    

class preprocess():
    
    def __init__(self):
        print("....")
        
    
    def dummys(self):
        pass
    
    def labelencoder(self):
        pass
    
    def standardisation(self):
        pass
    
    def fillna(self):
        pass
    
    
    def outlier_describing(self):
        pass
    

class information():
    def __init__(self):
        print("Tanimlayici degerler")
        
    def info(self):
        pass
    
    def frequencies(self):
        pass
